# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Automobile_insurance_fraud.csv")
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    25-01-2015  Single Vehicle Collision   Side Collision      Major Damage
# 1    21-01-2015             Vehicle Theft                ?      Minor Damage
# 2    22-02-2015   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    10-01-2015  Single Vehicle Collision  Front Collision      Major Damage
# 4    17-02-2015             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                  None             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip insured_sex insured_education_level insured_occupation  \
# 995       431289      FEMALE                 Masters       craft-repair
# 996       608177      FEMALE                     PhD     prof-specialty
# 997       442797      FEMALE                 Masters       armed-forces
# 998       441714        MALE               Associate  handlers-cleaners
# 999       612260      FEMALE               Associate              sales
#
#     insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 995       paintball            unmarried              0             0
# 996        sleeping                 wife          70900             0
# 997  bungie-jumping       other-relative          35100             0
# 998    base-jumping                 wife              0             0
# 999        kayaking              husband              0             0
#
#     incident_date             incident_type   collision_type  \
# 995    22-02-2015  Single Vehicle Collision  Front Collision
# 996    24-01-2015  Single Vehicle Collision   Rear Collision
# 997    23-01-2015   Multi-vehicle Collision   Side Collision
# 998    26-02-2015  Single Vehicle Collision   Rear Collision
# 999    26-02-2015                Parked Car                ?
#
#     incident_severity authorities_contacted incident_state incident_city  \
# 995      Minor Damage                  Fire             NC    Northbrook
# 996      Major Damage                  Fire             SC     Northbend
# 997      Minor Damage                Police             NC     Arlington
# 998      Major Damage                 Other             NY     Arlington
# 999      Minor Damage                Police             WV      Columbus
#
#        incident_location  incident_hour_of_the_day  \
# 995   6045 Andromedia St                        20
# 996     3092 Texas Drive                        23
# 997          7629 5th St                         4
# 998        6128 Elm Lane                         2
# 999  1416 Cherokee Ridge                         6
#
#      number_of_vehicles_involved property_damage  bodily_injuries  witnesses  \
# 995                            1             YES                0          1
# 996                            1             YES                2          3
# 997                            3               ?                2          3
# 998                            1               ?                0          1
# 999                            1               ?                0          3
#
#     police_report_available  total_claim_amount  injury_claim  property_claim  \
# 995                       ?               87200         17440            8720
# 996                       ?              108480         18080           18080
# 997                     YES               67500          7500            7500
# 998                     YES               46980          5220            5220
# 999                       ?                5060           460             920
#
#      vehicle_claim   auto_make auto_model  auto_year fraud_reported  _c39
# 995          61040       Honda     Accord       2006              N   NaN
# 996          72320  Volkswagen     Passat       2015              N   NaN
# 997          52500      Suburu    Impreza       1996              N   NaN
# 998          36540        Audi         A5       1998              N   NaN
# 999           3680    Mercedes       E400       2007              N   NaN

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 40)

# %% [markdown]
# # Observation

# %% [markdown]
# this dataset has 1000rows and 40 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %% [markdown]
# # Observation

# %% [markdown]
# We have integer,float,and object data in dataset

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# 25%              1089.607500    0.000000e+00  448404.500000       0.000000
# 50%              1257.200000    0.000000e+00  466445.500000       0.000000
# 75%              1415.695000    0.000000e+00  603251.000000   51025.000000
# max              2047.590000    1.000000e+07  620962.000000  100500.000000
#
#         capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# count    1000.000000               1000.000000                   1000.00000
# mean   -26793.700000                 11.644000                      1.83900
# std     28104.096686                  6.951373                      1.01888
# min   -111100.000000                  0.000000                      1.00000
# 25%    -51500.000000                  6.000000                      1.00000
# 50%    -23250.000000                 12.000000                      1.00000
# 75%         0.000000                 17.000000                      3.00000
# max         0.000000                 23.000000                      4.00000
#
#        bodily_injuries    witnesses  total_claim_amount  injury_claim  \
# count      1000.000000  1000.000000          1000.00000   1000.000000
# mean          0.992000     1.487000         52761.94000   7433.420000
# std           0.820127     1.111335         26401.53319   4880.951853
# min           0.000000     0.000000           100.00000      0.000000
# 25%           0.000000     1.000000         41812.50000   4295.000000
# 50%           1.000000     1.000000         58055.00000   6775.000000
# 75%           2.000000     2.000000         70592.50000  11305.000000
# max           2.000000     3.000000        114920.00000  21450.000000
#
#        property_claim  vehicle_claim    auto_year  _c39
# count     1000.000000    1000.000000  1000.000000   0.0
# mean      7399.570000   37928.950000  2005.103000   NaN
# std       4824.726179   18886.252893     6.015861   NaN
# min          0.000000      70.000000  1995.000000   NaN
# 25%       4445.000000   30292.500000  2000.000000   NaN
# 50%       6750.000000   42100.000000  2005.000000   NaN
# 75%      10885.000000   50822.500000  2010.000000   NaN
# max      23670.000000   79560.000000  2015.000000   NaN

# %% [markdown]
# # observation

# %% [markdown]
# we can see 50% and mean data months_as_customer,age data are skewed

# %%
df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           991
# umbrella_limit                   11
# insured_zip                     995
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    4
# incident_severity                 4
# authorities_contacted             5
# incident_state                    7
# incident_city                     7
# incident_location              1000
# incident_hour_of_the_day         24
# number_of_vehicles_involved       4
# property_damage                   3
# bodily_injuries                   3
# witnesses                         4
# police_report_available           3
# total_claim_amount              763
# injury_claim                    638
# property_claim                  626
# vehicle_claim                   726
# auto_make                        14
# auto_model                       39
# auto_year                        21
# fraud_reported                    2
# _c39                              0
# dtype: int64

# %% [markdown]
# # observaton

# %% [markdown]
# we have categorical values

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %% [markdown]
# # null value check

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# # observation

# %% [markdown]
# '_c39' column has all null values so dropping it

# %% [markdown]
# # Null value handling

# %%
df.drop(["_c39"],inplace=True,axis=1)

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# # observation

# %% [markdown]
# Null values are removed

# %% [markdown]
# # univariate analysis

# %%
sns.countplot(df ['policy_state'])
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %% [markdown]
# # Observation

# %% [markdown]
# OH,IN,IL have equal amount of data

# %%
sns.countplot(df['policy_csl'])
# Out:
# <AxesSubplot:xlabel='policy_csl', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# 250/500 , 100/300,500/1000 have equal amount of data

# %%
plt.figure(figsize=(10,10))
sns.countplot(df[ 'insured_education_level'])
# Out:
# <AxesSubplot:xlabel='insured_education_level', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# High School is higher compared to other education level

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['insured_occupation'])
# Out:
# <AxesSubplot:xlabel='insured_occupation', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# Machine-op-inspct occupation is higher compared to others

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['incident_type'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# MultiVechile Collision is high compared to other incidents

# %%
sns.countplot(df['collision_type'])
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# Rear Collision is high compared to other collisoins

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['incident_severity'])
# Out:
# <AxesSubplot:xlabel='incident_severity', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# Minor Damage in incident_severity is high copared to others

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['authorities_contacted'])
# Out:
# <AxesSubplot:xlabel='authorities_contacted', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# Police is contacted most in authorities contacted

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['incident_state'])
# Out:
# <AxesSubplot:xlabel='incident_state', ylabel='count'>

# %% [markdown]
# # Observation

# %% [markdown]
# NY is higher incident state compared to others

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['incident_city'])
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# Springfield incident city is higher compared to other city

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['number_of_vehicles_involved'])
# Out:
# <AxesSubplot:xlabel='number_of_vehicles_involved', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# Vehicle involved in collision is 1 most

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['property_damage'])
# Out:
# <AxesSubplot:xlabel='property_damage', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['bodily_injuries'])
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='count'>

# %% [markdown]
# # Observation

# %% [markdown]
# Body injuries is 0 most

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['witnesses'])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# 'witnesses' are mostly 1

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['police_report_available'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# No police report available is no moslty

# %%
plt.figure(figsize=(20,10))
sns.countplot(df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# No fraud Reported in most of the cases

# %% [markdown]
# Data imbalance is found so we need to use SMOTE

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(10,10))
sns.barplot(df[ 'fraud_reported'],df[ 'total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='total_claim_amount'>

# %% [markdown]
# # Observation

# %% [markdown]
# Claim amount is higher for fraud cases

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['umbrella_limit'],df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='fraud_reported'>

# %% [markdown]
# # Observation

# %% [markdown]
# Fraud cases have higher umbrella limit

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df[ 'collision_type'],df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='fraud_reported'>

# %% [markdown]
# # observation

# %% [markdown]
# Rear collision have higher fraud claims

# %%
plt.figure(figsize=(10,10))
sns.barplot(df[ 'witnesses'],df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='fraud_reported'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df[ 'witnesses'],df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='fraud_reported'>

# %% [markdown]
# # observations

# %% [markdown]
# Fraud reported is higher with increase in witness

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df['police_report_available'],df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='fraud_reported'>

# %% [markdown]
# # Observation

# %% [markdown]
# Fraud report is higher without police report

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df['insured_sex'],df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='fraud_reported'>

# %% [markdown]
# # Observation

# %% [markdown]
# Male have higher fraud claims

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df['policy_annual_premium'],df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='total_claim_amount'>

# %% [markdown]
# # observation

# %% [markdown]
# Totoal Claim amount is positively correlated with policy annual premium

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['incident_type'],df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='total_claim_amount'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df['incident_type'],df['total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='total_claim_amount'>

# %% [markdown]
# # observation

# %% [markdown]
# For Single vehicle collison total claim amount is higher

# %%
plt.figure(figsize=(10,10))
sns.barplot(df['incident_city'],df[ 'total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='total_claim_amount'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df['incident_city'],df[ 'total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='incident_city', ylabel='total_claim_amount'>

# %% [markdown]
# # Observation

# %% [markdown]
# SpringFieldIncident_city has higer claim amount

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df[ 'incident_type'],df[ 'fraud_reported'])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='fraud_reported'>

# %% [markdown]
# # Observation

# %% [markdown]
# Single Vehicle Collison and Mult-Vehicle collision has higher fraud reported

# %%
plt.figure(figsize=(30,10))
sns.lineplot(df['insured_occupation'],df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='insured_occupation', ylabel='fraud_reported'>

# %% [markdown]
# # Observation

# %% [markdown]
# exec-manageral occupation has higher fruad reported

# %%
sns.pairplot(df.iloc[:,0:15])

# %%
sns.pairplot(df.iloc[:,15:30])

# %%
sns.pairplot(df.iloc[:,30:40])

# %% [markdown]
# # observation

# %% [markdown]
# Total claim amount and vehicle claim are positively correalted

# %% [markdown]
# Vehicle claim and property claim are positively correalted

# %% [markdown]
# vehicle claim and total amount claim are positively correlated

# %% [markdown]
# months as customer age are positively correlated

# %% [markdown]
# # Encoding

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    25-01-2015  Single Vehicle Collision   Side Collision      Major Damage
# 1    21-01-2015             Vehicle Theft                ?      Minor Damage
# 2    22-02-2015   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    10-01-2015  Single Vehicle Collision  Front Collision      Major Damage
# 4    17-02-2015             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                  None             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported
# 0       2004              Y
# 1       2007              Y
# 2       2007              N
# 3       2014              Y
# 4       2009              N

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# incident_location               object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available         object
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                       object
# auto_model                      object
# auto_year                        int64
# fraud_reported                  object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
list1 = ['policy_state','policy_csl','insured_sex','insured_education_level','insured_occupation','insured_hobbies','insured_relationship','incident_date','incident_type','collision_type','incident_severity','authorities_contacted','incident_state','incident_city','incident_location','property_damage','police_report_available','auto_make','auto_model']

# %%
df["Day"] = pd.to_datetime(df['policy_bind_date']).dt.day
df["Month"] = pd.to_datetime(df['policy_bind_date']).dt.month
df["Year"] = pd.to_datetime(df['policy_bind_date']).dt.year
df.drop('policy_bind_date',axis=1,inplace=True)

# %%
df1 = pd.DataFrame()
for i in list1:
    df1[i] = df[i]

# %%
a = pd.get_dummies(df1)

# %%
df['fraud_reported'] = LabelEncoder().fit_transform(df["fraud_reported"])

# %%
df.drop(['policy_state','policy_csl','insured_sex','insured_education_level','insured_occupation','insured_hobbies','insured_relationship','incident_date','incident_type','collision_type','incident_severity','authorities_contacted','incident_state','incident_city','incident_location','property_damage','police_report_available','auto_make','auto_model'],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# capital-gains                    int64
# capital-loss                     int64
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# bodily_injuries                  int64
# witnesses                        int64
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_year                        int64
# fraud_reported                   int32
# Day                              int64
# Month                            int64
# Year                             int64
# dtype: object

# %% [markdown]
# # Observation

# %% [markdown]
# we have succesfully converted all object data to numeric data.

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap="YlOrBr")
# Out:
# <AxesSubplot:>

# %%
df.corr()['fraud_reported'].sort_values(ascending=False)
# Out:
# fraud_reported                 1.000000
# vehicle_claim                  0.170049
# total_claim_amount             0.163651
# property_claim                 0.137835
# injury_claim                   0.090975
# Day                            0.060643
# umbrella_limit                 0.058622
# number_of_vehicles_involved    0.051839
# witnesses                      0.049497
# bodily_injuries                0.033877
# months_as_customer             0.020544
# insured_zip                    0.019368
# policy_deductable              0.014817
# age                            0.012143
# auto_year                      0.007928
# incident_hour_of_the_day       0.004316
# Year                          -0.000059
# policy_annual_premium         -0.014480
# capital-loss                  -0.014863
# capital-gains                 -0.019173
# policy_number                 -0.029443
# Month                         -0.030829
# Name: fraud_reported, dtype: float64

# %% [markdown]
# # observation

# %% [markdown]
# Vehicle_claim,Total_claim_amount,property claim are positively correlated with Fraud_reported

# %% [markdown]
# Other feautures are very less correlated with Fraud_reported

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df[ 'fraud_reported'],df[ 'vehicle_claim'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='vehicle_claim'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df[ 'fraud_reported'],df[ 'vehicle_claim'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='vehicle_claim'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df[ 'fraud_reported'],df[ 'total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='total_claim_amount'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df[ 'fraud_reported'],df[ 'total_claim_amount'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='total_claim_amount'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df[ 'fraud_reported'],df[ 'property_claim'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='property_claim'>

# %%
plt.figure(figsize=(10,10))
sns.lineplot(df[ 'fraud_reported'],df[ 'property_claim'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='property_claim'>

# %% [markdown]
# # Skewness

# %%
dc1 = df.drop(['fraud_reported',"Day","Month","Year"],axis=1)

# %%
dc1.plot(kind="hist",subplots=True,layout=(5,5),figsize=(40,20))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %%
dc1.skew().sort_values(ascending=False)
# Out:
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# number_of_vehicles_involved    0.502664
# age                            0.478988
# capital-gains                  0.478850
# policy_deductable              0.477887
# property_claim                 0.378169
# months_as_customer             0.362177
# injury_claim                   0.264811
# policy_number                  0.038991
# witnesses                      0.019636
# bodily_injuries                0.014777
# policy_annual_premium          0.004402
# incident_hour_of_the_day      -0.035584
# auto_year                     -0.048289
# capital-loss                  -0.391472
# total_claim_amount            -0.594582
# vehicle_claim                 -0.621098
# dtype: float64

# %% [markdown]
# # observation

# %% [markdown]
# Many features have skewness

# %%
from sklearn.preprocessing import power_transform
dc2 = power_transform(dc1)

# %%
dc2 = pd.DataFrame(dc2,columns=dc1.columns)

# %%
dc2.skew()
# Out:
# months_as_customer            -0.135661
# age                           -0.001945
# policy_number                 -0.160374
# policy_deductable              0.023988
# policy_annual_premium          0.004758
# umbrella_limit                -7.865930
# insured_zip                    0.000000
# capital-gains                  0.038722
# capital-loss                   0.090488
# incident_hour_of_the_day      -0.256957
# number_of_vehicles_involved    0.363693
# bodily_injuries               -0.128799
# witnesses                     -0.153648
# total_claim_amount            -0.510354
# injury_claim                  -0.415781
# property_claim                -0.358814
# vehicle_claim                 -0.522718
# auto_year                     -0.012491
# dtype: float64

# %% [markdown]
# # observation

# %% [markdown]
# we have removed skewness

# %% [markdown]
# # outlier removal

# %%
dc2.plot(kind="box",subplots=True,figsize=(20,20))
# Out:
# months_as_customer                AxesSubplot(0.125,0.125;0.036215x0.755)
# age                            AxesSubplot(0.168458,0.125;0.036215x0.755)
# policy_number                  AxesSubplot(0.211916,0.125;0.036215x0.755)
# policy_deductable              AxesSubplot(0.255374,0.125;0.036215x0.755)
# policy_annual_premium          AxesSubplot(0.298832,0.125;0.036215x0.755)
# umbrella_limit                  AxesSubplot(0.34229,0.125;0.036215x0.755)
# insured_zip                    AxesSubplot(0.385748,0.125;0.036215x0.755)
# capital-gains                  AxesSubplot(0.429206,0.125;0.036215x0.755)
# capital-loss                   AxesSubplot(0.472664,0.125;0.036215x0.755)
# incident_hour_of_the_day       AxesSubplot(0.516121,0.125;0.036215x0.755)
# number_of_vehicles_involved    AxesSubplot(0.559579,0.125;0.036215x0.755)
# bodily_injuries                AxesSubplot(0.603037,0.125;0.036215x0.755)
# witnesses                      AxesSubplot(0.646495,0.125;0.036215x0.755)
# total_claim_amount             AxesSubplot(0.689953,0.125;0.036215x0.755)
# injury_claim                   AxesSubplot(0.733411,0.125;0.036215x0.755)
# property_claim                 AxesSubplot(0.776869,0.125;0.036215x0.755)
# vehicle_claim                  AxesSubplot(0.820327,0.125;0.036215x0.755)
# auto_year                      AxesSubplot(0.863785,0.125;0.036215x0.755)
# dtype: object

# %%
dc2.shape
# Out:
# (1000, 18)

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(dc2))

# %%
np.where(z>3)
# Out:
# (array([229, 248, 290, 763], dtype=int64), array([4, 4, 5, 4], dtype=int64))

# %%
df1 = dc2

# %%
df1.drop([229, 248, 290, 763],axis=0,inplace=True)

# %%
df1.shape
# Out:
# (996, 18)

# %% [markdown]
# # observation

# %% [markdown]
# the outliers are removed

# %% [markdown]
# # data loss

# %%
((1000-996)/1000)*100
# Out:
# 0.4

# %% [markdown]
# # observation

# %% [markdown]
# 0.4% Data loss

# %% [markdown]
# # creating categorical data dataframe

# %%
dfd = pd.DataFrame()
dfd['fraud_reported'] = df['fraud_reported']
dfd["Day"] = df["Day"]
dfd["Month"] = df["Month"]
dfd["Year"] = df["Year"]
dfd = dfd.join(a)
dfd.shape
# Out:
# (1000, 1209)

# %% [markdown]
# # removing the outlier removed rows in categorical dataframe

# %%
dfd.drop([229, 248, 290, 763],axis=0,inplace=True)

# %%
dfd.shape
# Out:
# (996, 1209)

# %% [markdown]
# # Data Balancing

# %%
sns.countplot(dfd.iloc[:,0])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# # Observations

# %% [markdown]
# The Data is imbalanced so we need to balance it

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()

# %%
dfb = df1.join(dfd)
dx = dfb.drop("fraud_reported",axis=1)
dy = dfd.iloc[:,0]
dft,y = sm.fit_resample(dx,dy)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %% [markdown]
# # Observations

# %% [markdown]
#  data is now balanced

# %% [markdown]
# # Standard Scaler

# %%
sc1=dft.iloc[:,0:18]

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x1=sc.fit_transform(sc1)
sc_final = pd.DataFrame(x1,columns=sc1.columns)

# %% [markdown]
# # Observation

# %% [markdown]
# Now we have scaled the data

# %% [markdown]
# # PCA

# %%
x_input.shape
# Out:
# (1500, 1226)

# %%
x_input = sc_final.join(dft.iloc[:,18:])

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(dft)
fig, ax = plt.subplots(figsize=(20,10))
xi = np.arange(1, 1227, step=1)
yi = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, yi, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 1227, step=1)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=1, color='r', linestyle='-')
plt.text(0.5, 0.85, '100% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt
# 1171  1.000000
# 1172  1.000000
# 1173  1.000000
# 1174  1.000000
# 1175  1.000000
# 1176  1.000000
# 1177  1.000000
# 1178  1.000000
# 1179  1.000000
# 1180  1.000000
# 1181  1.000000
# 1182  1.000000
# 1183  1.000000
# 1184  1.000000
# 1185  1.000000
# 1186  1.000000
# 1187  1.000000
# 1188  1.000000
# 1189  1.000000
# 1190  1.000000
# 1191  1.000000
# 1192  1.000000
# 1193  1.000000
# 1194  1.000000
# 1195  1.000000
# 1196  1.000000
# 1197  1.000000
# 1198  1.000000
# 1199  1.000000
# 1200  1.000000
# 1201  1.000000
# 1202  1.000000
# 1203  1.000000
# 1204  1.000000
# 1205  1.000000
# 1206  1.000000
# 1207  1.000000
# 1208  1.000000
# 1209  1.000000
# 1210  1.000000
# 1211  1.000000
# 1212  1.000000
# 1213  1.000000
# 1214  1.000000
# 1215  1.000000
# 1216  1.000000
# 1217  1.000000
# 1218  1.000000
# 1219  1.000000
# 1220  1.000000
# 1221  1.000000
# 1222  1.000000
# 1223  1.000000
# 1224  1.000000
# 1225  1.000000

# %% [markdown]
# # we can see for 1110 columns i wont loose any data so i set threshold to 1110 for PCA

# %%
pca = PCA(n_components=1110)
p_final=pca.fit_transform(x_input)

# %%
x_final = pd.DataFrame(p_final)

# %% [markdown]
# # Multicolinearity Checking

# %% [markdown]
# # variance inflation factor

# %%
x_final.shape
# Out:
# (1500, 1110)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["vif value"] = [variance_inflation_factor(x_final.values,a) for a in range(1110)]
vif["feature names"] = x_final.columns

# %%
vif.sort_values(by=["vif value"],ascending=False).head()

# %% [markdown]
# # Observation

# %% [markdown]
# No Mulitcolinearity as PCA TAKES care of mulitcolinearity

# %% [markdown]
# # model Training starts

# %% [markdown]
# # Importing required libraries

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # i have write a code block that tests data with models and rank them according to cross val score and accuracy score

# %%
algo = [DecisionTreeClassifier(),KNeighborsClassifier(),RandomForestClassifier(),AdaBoostClassifier(),LogisticRegression()]
result = pd.DataFrame(columns=["Algorithm Name","Accuracy Score","Cross Validation Score"])

dtc=[]
knc=[]
rfc=[]
abc=[]
lr=[]
fl = [dtc,knc,rfc,abc,lr]

oo=0

for i in algo:
    rand=0
    acc=0    
    
    for ii in range(10):
        train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=ii)
        cf = i
        cf.fit(train_x,train_y)
        pred = cf.predict(test_x)
        ac = accuracy_score(test_y,pred)
        if ac>acc:
            acc=ac
            rand=ii
    print(f' the best random state is {rand} and accuracy score is {acc} for algorithm {i}')
    
    
    train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=rand)
    cf = i
    cf.fit(train_x,train_y)
    pred = cf.predict(test_x)
    ac = accuracy_score(test_y,pred)
    cv = cross_val_score(cf,x_final,y,cv=5).mean()
    fl[oo].insert(0,i)
    fl[oo].insert(1,ac)
    fl[oo].insert(2,cv)
    result.loc[oo] = fl[oo]
    oo +=1
    
    
final_result = result.sort_values(by=["Accuracy Score","Cross Validation Score"],ascending=False)
# Out:
#  the best random state is 1 and accuracy score is 0.8366666666666667 for algorithm DecisionTreeClassifier()
#  the best random state is 4 and accuracy score is 0.6533333333333333 for algorithm KNeighborsClassifier()
#  the best random state is 1 and accuracy score is 0.8666666666666667 for algorithm RandomForestClassifier()
#  the best random state is 6 and accuracy score is 0.8633333333333333 for algorithm AdaBoostClassifier()
#  the best random state is 1 and accuracy score is 0.9 for algorithm LogisticRegression()

# %%
final_result
# Out:
#                                       Algorithm Name  Accuracy Score  \
# 4                               LogisticRegression()        0.900000
# 2  (DecisionTreeClassifier(max_features='auto', r...        0.866667
# 3  (DecisionTreeClassifier(max_depth=1, random_st...        0.863333
# 0                           DecisionTreeClassifier()        0.816667
# 1                             KNeighborsClassifier()        0.653333
#
#    Cross Validation Score
# 4                0.852667
# 2                0.836000
# 3                0.822667
# 0                0.768000
# 1                0.616667

# %%
final_result.loc[4]["Algorithm Name"]
# Out:
# LogisticRegression()

# %% [markdown]
# # running Support vector classifier induvidually as it consumes more memory

# %%
svc = SVC()
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=10)
svc.fit(train_x,train_y)
pred = svc.predict(test_x)
ac = accuracy_score(test_y,pred)
cv = cross_val_score(svc,x_final,y,cv=5).mean()
print(f' the accuracy socre is {ac}, the cross validation score is {cv} for SVC' )
# Out:
#  the accuracy socre is 0.88, the cross validation score is 0.8293333333333333 for SVC

# %% [markdown]
# # Observation

# %% [markdown]
# from all the classifier models Logistic Regression performed best with accuracy of 90 % and cross val score of 85 %

# %% [markdown]
# # HyperParameter Tunining

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf = LogisticRegression()
parameters = {'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
 'penalty': ['l1', 'l2', 'elasticnet', 'none'],
 'dual': [True,False],
 'fit_intercept': [True,False],
             "max_iter":[100,150]}
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=1)
gsv = GridSearchCV(rf,parameters)
gsv.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'dual': [True, False], 'fit_intercept': [True, False],
#                          'max_iter': [100, 150],
#                          'penalty': ['l1', 'l2', 'elasticnet', 'none'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']})

# %%
gsv.best_params_
# Out:
# {'dual': False,
#  'fit_intercept': True,
#  'max_iter': 150,
#  'penalty': 'none',
#  'solver': 'saga'}

# %% [markdown]
# # using the best parameters got in grid search

# %%
rf = LogisticRegression(dual=False,fit_intercept=True,max_iter=150,penalty='none',solver='saga')
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=15)
rf.fit(train_x,train_y)
pred = rf.predict(test_x)
ac = accuracy_score(test_y,pred)
cv = cross_val_score(rf,x_final,y,cv=5).mean()
print(f' the accuracy socre is {ac}, the cross validation score is {cv} ' )
# Out:
#  the accuracy socre is 0.9, the cross validation score is 0.8586666666666666

# %% [markdown]
# # Observation

# %% [markdown]
# the accuracy score is 90% and cross validation score is 86%

# %%
print(classification_report(test_y,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       150
#            1       0.91      0.89      0.90       150
#
#     accuracy                           0.90       300
#    macro avg       0.90      0.90      0.90       300
# weighted avg       0.90      0.90      0.90       300

# %%
print(confusion_matrix(test_y,pred))
# Out:
# [[137  13]
#  [ 17 133]]

# %% [markdown]
# # ROC_AUC_CURVE

# %%
from sklearn.metrics import plot_roc_curve,roc_auc_score

# %%
print(f'The Roc Auc Score is {roc_auc_score(test_y,pred)}')
# Out:
# The Roc Auc Score is 0.9

# %%
plot_roc_curve(rf,test_x,test_y)

# %% [markdown]
# # saving the model

# %%
import joblib
joblib.dump(rf,"Insurance Claims.pkl")
# Out:
# ['Insurance Claims.pkl']
